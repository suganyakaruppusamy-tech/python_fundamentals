# %% [markdown]
# <a href="https://colab.research.google.com/github/suganyakaruppusamy-tech/python_fundamentals/blob/main/python_fundamentals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Case Study – Library Fine Calculator Instructions:
#
# Create variables:
#
# student_name
#
# book_name
#
# days_late
#
# fine_per_day
#
# Use input() function to get details from the user.
#
# Use type casting:
#
# int() for days_late
#
# float() for fine_per_day
#
# Calculate:
#
# total_fine = days_late * fine_per_day
#
# Display all details using:
#
# print()

# %%
# Student Registration System Instructions:
# Use input() function to get details from the user

student_name=input("student_name:")
print(type(student_name))
print(id(student_name))
student_age=input("student_age:")
print(type(student_age))
print(id(student_age))
course_name=input("course_name:")
print(type(course_name))
print(id(course_name))
course_fee=input("course_fee:")
print(type(course_fee))
print(id(course_fee))

# Use type casting:
student_age=int(input("student_age:"))
course_fee=float(input("course_fee:"))

# Calculate:
GST= course_fee*0.18
total_fee=course_fee+GST
print("GST:",GST)
print("total_fee:",total_fee)

# %% [markdown]
# Case Study – Library Fine Calculator
# Instructions:
#
# Create variables:
#
# student_name
#
# book_name
#
# days_late
#
# fine_per_day
#
# Use input() function to get details from the user.
#
# Use type casting:
#
# int() for days_late
#
# float() for fine_per_day
#
# Calculate:
#
# total_fine = days_late * fine_per_day
#
# Display all details using:
#
# print()
#
# f-string
#
# Display datatype of important variables using:
#
# type()
#
# """

# %%
# library fine calculator
#Taking inputs from the users

student_name= input("Enter student name: ")
Book_name= input("Enter Book_name: ")
Days_late= int(input("Enter Days_late: "))
Fine_per_day= float(input("Enter Fine_per_day: "))

#calulation
total_fine = Days_late * Fine_per_day

# Display all details
print("\n----User Details----")
print(f"Student Name : {student_name}")
print(f"Book Name : {Book_name}")
print(f"Days_late : {Days_late}")
print(f"Fine per Day : {Fine_per_day}")
print(f"Total fine : {total_fine}")

# %% [markdown]
# Case Study – Email Username Generator Instructions:
#
# • Create variables: full_name, domain_name
#
# • Take input from the user using input() function
#
# • Convert full_name into lowercase using lower()
#
# • Remove spaces in name and replace with dot using replace()
#
# • Split full_name using split() function
#
# • Join name parts using join() function if needed
#
# • Create email in format: name@domain
#
# • Display only Full Name and Generated Email
#
# • Use print() and f-string for output display
#
# """
#
# ---

# %%
full_name=input("enter full name:")
domain_name=input("enter domain name:")
lower_case= full_name.lower()
print(lower_case)
email_name=lower_case.replace(" ",".")
print(email_name)
email=email_name+"@"+domain_name+".in"
print(email)

# %% [markdown]
# """
#
# Case Study – Student ID Card Generator
# Instructions:
#
# • Create variables: student_name, roll_number, department
#
# • Take input from the user using input() function
#
# • Convert student_name and department into uppercase using upper()
#
# • Extract first 4 letters of student_name and department using slicing
#
# • Create Student ID by combining name, department, and roll number
#
# • Display Name, Department, Roll Number, and Student ID only
#
# • Use print() and f-string for output display
# """

# %%
#creating a variable
student_id=("student_name","roll_number","department")
print(student_id)

#taking input from the user
student_name = input(f"enter the student_name: ")
roll_number=input("Enter the Roll Number: ")
Department=input("Enter the Department: ")

#convert student_name and department into uppercase
upper_name=student_name.upper()
upper_department=Department.upper()

#Extract first 4 letters of student_name and department using slicing
student_4= student_name[:4]
dept_4=  Department[:4]

#create student_ID
student_id = student_4 + "_" + dept_4 + "_" + roll_number

#Display name, department, Roll number, Student ID
print(f"name :{upper_name}")
print(f"department :{upper_department}")
print(f"roll_number :{roll_number}")
print(f"student_id :{student_id}")

# %% [markdown]
# Case Study – Online Order Summary using Tuple Instructions:
#
# Create a tuple named order with the following details: order_id, product_name, quantity, price, status
#
# Unpack the tuple into separate variables: order_id, product, quantity, price, status
#
# Display all order details using print() and f-string

# %%
#tuple creation
order =(1001,"smart phone",2,"packed")
print(f"packed tuple: {order}")

#unpacking the tuple
order_id, product_name, quantity, status=order
print("\n----Unpacked Tuple----")
print(f"order ID : {order_id}")
print(f"Product name : {product_name}")
print(f"Quantity : {quantity}")
print(f"Order Status : {status}")

# %% [markdown]
# Case Study – Student Details using Tuple (Packing & Unpacking)
# Instructions:
#
# Create a tuple named student and store the following details: name, age, course
#
# Unpack the tuple into separate variables: name, age, course
#
# Display each value separately using print().

# %%
# creating  packed tuple
student =("Ravi",19,"ECE")
print(f"packed student details : {student}")

# unpacked tuple
name , age, course =student
print("\n***unpacked student details***")
print(f"Student name : {name}")
print(f"Age : {age}")
print(f"Course : {course}")

#modify the tuple
age=20
print(age)

#repack tuple
student = name, age, course
print(f"Repacked tuple : {student}")

# %% [markdown]
# Case Study – Shopping Cart System
# Instructions:
#
# Create a list named cart with initial items: Milk, Bread, Eggs, Apple
#
# Perform list operations:
#
# • Add multiple items using extend()
#
# • Insert item at index 2 using insert()
#
# • Remove item Apple using remove()
#
# • Remove last item using pop()
#
# Use list methods:
#
# • index() to find position of Eggs
#
# • count() to count occurrences of Milk
#
# Apply indexing:
#
# • Display first item
#
# • Display last item
#
# Apply slicing:
#
# • Display first 3 items from the list
#
# Find total number of items using len()
#
# Display all outputs using print()

# %%
#creation
initial_item=["milk","bread","apple","eggs","milk","apple","eggs"]
print(f"\ninitial items:{initial_item}")

#extend
initial_item.extend(["chicken","biscuits"])
print(f"\nextend item:{initial_item}")

#insert
initial_item.insert(2,"strwberries")
print(f"\ninserted item:{initial_item}")

#remove
initial_item.remove("apple")
print(f"\nafter removing a item:{initial_item}")

#pop
initial_item.pop()
print(f"\nafter poping a item:{initial_item}")

#index
indexing =initial_item.index("eggs")
print(f"\nindexing_egg:{indexing}")

#count
counting =initial_item.count("milk")
print(f"\ncounting_milk:{counting}")

#apply indexing
Display0=initial_item[0]
print(f"\ndisplaying 1st item:{Display0}")

#displaying last item
displaylast = initial_item[-1]
print(f"\nDisplaying last item : {displaylast}")
print(f"\nfinal list : {initial_item}")

# %% [markdown]
# Case Study – Student Data Management System
# Instructions:
#
# Create a dictionary named student with the following keys: name, age, course
#
# Store multiple students' data using lists as values.
#
# Add one new student details to the dictionary:
#
# • Append new name to name list
#
# • Append new age to age list
#
# • Append new course to course list
#
# Display all student details using dictionary keys.
#
# Access and display:
#
# • First student's details using indexing
#
# • Newly added student's details using indexing

# %%
# Store multiple students' data using lists as values.
student ={"name":["suganya","surya","renuka","vishnu"],
          "age":[33,34,31,32],
          "course": ["python","medicine","software","web developer"]}

# Add one new student details to the dictionary:
student["name"].append("sandhya")
student["age"].append(35)
student["course"].append("cookery")

#Display all student details using dictionary keys.
print(student)

# First student's details using indexing
print("\n----First student's Detail----")
print(f"1st student name: {student["name"][0]}")
print(f"1st student age: {student["age"][0]}")
print(f"1st student course: {student["course"][0]}")
#  Newly added student's details using indexing
print("\n----Newly added student's Detail----")
print(f"new student name: {student["name"][4]}")
print(f"new student age: {student["age"][4]}")
print(f"new student course: {student["course"][4]}")

# %% [markdown]
# Case Study – Student Course Registration System using Set
# Instructions:
#
# Create a set named courses with course names: Python, SQL, Power BI, Python, Excel
#
# Perform set operations: • Add course using add()
# • Add multiple courses using update()
# • Remove course using remove() and discard()
#
# Display all courses and total number of courses using len()

# %%
# create a set named course
course = {"python", "SQL", "Power BI", "Python", "Excel"}

# Add course using add()
course.add("machine learning")

# Add multiple courses using update()
course.update(["desgin","web development","developer"])
print(course)

# %% [markdown]
# ##  **5. Case Study: Bank Loan Eligibility System**
# **Instructions:**
#
# 1. Create variables:
#    customer_name, age, income, credit_score, existing_loan
#
# 2. Use conditional statements (if, elif, else) to:
#
#    • Approve loan if age ≥ 21, income ≥ 30000,
#
#    -- credit_score ≥ 700, and no existing loan
#
#    • Conditionally approve loan if credit_score ≥ 600 and income ≥ 40000
#
#    • Otherwise reject the loan application
#
# 3. Display customer details and loan status using print()

# %%
custumer_name = input("enter the name:")
age= int(input("enter the age:"))
income=int(input("enter the income:"))
credit_score= int(input("enter credit score:"))
existing_loan = False
#conditional statement
if age >=21 and income > 30000:
   if credit_score>=700 and not existing_loan == True:
      print("the person is elegibel for loan")
   else:
      print("conditional approval")
else:
  print("rejected")

# %% [markdown]
# ## **Case Study Scholarship Eligibility Checker**
#
# **Instructions:**
#
# 1. Create variables: `student_name`, `marks`, `attendance`, `family_income`.
# 2. Use conditional statements (`if`, `elif`, `else`) to:
#
#    * Award **Full Scholarship** if marks ≥ 90 and attendance ≥ 90.
#    * Award **Half Scholarship** if marks ≥ 80 or attendance ≥ 85.
#    * Award **Need-Based Scholarship** if marks ≥ 70 and `family_income` < 30000.
#    * Otherwise, display **Not Eligible**.
# 3. Display all data (no loops).

# %%
student_name= input("enter student name for scholarship:")
marks = int(input("enter your marks :"))
attendence = int(input("enter your attendence:"))
family_income= int(input("enter the family income:"))
if marks>=90 and attendence>=90:
  print("Full scholarship")
elif marks>=80 and attendence>=85:
  print("half scholarship")
elif marks >=70 and family_income<30000:
  print("need-Based Scholarship")
else:
  print("not eligible")

# %% [markdown]
# ## **Case Study – Student Marks Filter System using continue**
#
# **Instructions:**
#
# 1. Create two lists:
#    • students
#    • marks
#
# 2. Use a while loop to iterate through the student list.
#
# 3. Check student marks using if condition.
#
# 4. Use continue statement to:
#    • Skip students who scored 50 or above
#
# 5. Display only students who scored below 50.
#
# 6. Print student name and marks using f-string

# %%
students =["anu","abi","balu","mohan","renu"]
marks=[47,88,92,89,35]
i=students[0]

while i<len(students):
  if marks[i]>50:
    continue

i+=1
print(f"{students[i]} scored {marks[i]} below 50")

# %% [markdown]
# Case Study – Text Analyzer System
# Instructions:
#
# Take a string input from the user using input().
#
# Convert the text into lowercase using lower().
#
# Use a for loop to iterate through each character in the string.
#
# Count: • Total vowels
# • Total consonants
# • Total digits
# • Total special characters
#
# Use: • isalpha() for alphabets
# • isdigit() for numbers
#
# Display all counts using print()

# %%
user_input= input("enter the string").lower()
v = c = d= sc=0
for input in user_input:
  if input in "aeiou":
    v+=1
  elif input.isalpha():
    c+=1
  elif input.isdigit():
    d+=1
  else:
    sc+=1
print(f"total vowles:{v}, \n total consonant:{c}, total digit:{d}, total special character:{sc}")

# %% [markdown]
# ## **Case Study – Password Verification System**
#
# **Instructions:**
#
# 1. Create a variable named `password` with a default password value.
#
# 2. Take password input from the user using input().
#
# 3. Use a while loop to:
#    • Check whether the entered password matches the original password
#    • Display "Incorrect password... try again" if password is wrong
#    • Ask user to re-enter password until correct password is entered
#
# 4. Display "Access granted" when the correct password is entered

# %%
password = "neverforget"

user_password=input("enter the password:")


while user_password!=password:
  print("Incorrect password... try again")
  user_password= input("enter the password:")


else:
  print("access granted")

# %% [markdown]
# ## **Case Study – ATM PIN Verification System**
#
# **Instructions:**
#
# 1. Create a variable named `correct_pin` with a default PIN number.
#
# 2. Use a while loop to repeatedly ask the user to enter the PIN.
#
# 3. Check whether the entered PIN matches the correct PIN.
#
# 4. If the PIN is correct:
#    • Display "Login Successful"
#    • Stop the loop using break
#
# 5. Otherwise:
#    • Display "Incorrect PIN... Try Again"

# %%
correct_pin = "2324"

while True:
  user_pin=input("enter your pin")
  if user_pin == correct_pin:
   print("login successful")
   break
  else:
   print("incorrect pin.. try again")

# %% [markdown]
# ## **Case Study – Password Verification System with Limited Attempts**
#
# **Instructions:**
#
# 1. Create variables:
#    • password
#    • attempts
#    • max_attempts
#
# 2. Use a while loop to allow the user to enter the password.
#
# 3. Check whether the entered password matches the original password.
#
# 4. If the password is correct:
#    • Display "Access granted!"
#    • Stop the loop using break
#
# 5. If the password is incorrect:
#    • Increase attempt count
#    • Display remaining attempts
#
# 6. If maximum attempts are reached:
#    • Display "Maximum attempts reached. Access denied!"

# %%
password="2345"
attempts=0
max_attempts=3
while attempts<max_attempts:
  user_input= input("enter the passwprd:")
  if user_input==password:
    print("access granted")
    break
  else:
    attempts += 1
    print(f"access denied!, ({max_attempts-attempts} remaining)")
  if attempts== max_attempts:
    print("maximum attempts reached. Access denied!")

# %% [markdown]
# ## **Case Study – Student Marks Filter System using continue**
#
# **Instructions:**
#
# 1. Create two lists:
#    • students
#    • marks
#
# 2. Use a while loop to iterate through the student list.
#
# 3. Check student marks using if condition.
#
# 4. Use continue statement to:
#    • Skip students who scored 50 or above
#
# 5. Display only students who scored below 50.
#
# 6. Print student name and marks using f-string

# %%
students=["anu","abi","aathi","aaru","mithran"]
marks=[41,65,34,29,52]
i=0
while  i< len(students):
  if marks[i]>=50:
   i+=1
   continue
  print(f"{students[i]} has scored {marks[i]} (below 50)")
  i+=1
# Out:
# anu has scored 41 (below 50)
# aathi has scored 34 (below 50)
# aaru has scored 29 (below 50)

# %% [markdown]
# ## **Case Study – Text Analyzer System**
#
# **Instructions:**
#
# 1. Take a string input from the user using input().
#
# 2. Convert the text into lowercase using lower().
#
# 3. Use a for loop to iterate through each character in the string.
#
# 4. Count:
#    • Total vowels
#    • Total consonants
#    • Total digits
#    • Total special characters
#
# 5. Use:
#    • isalpha() for alphabets
#    • isdigit() for numbers
#
# 6. Display all counts using print()

# %%
intake=("#Sugi@2100Ramesh#")
intake.lower()
v=d=c=sc=0
for letter in intake:
 if letter in "aeiou":
  v+=1
 elif letter.isalpha():
    c+=1
 elif letter.isdigit():
      d+=1
 else:
        sc+=1
print(f"total vowels:{v}, total consonant:{c}, total digits:{d},total special character:{sc}")
# Out:
# total vowels:4, total consonant:6, total digits:4,total special character:3

# %% [markdown]
# Case Study – Restricted Word Detection System
# Instructions:
#
# Create a list of words containing normal and restricted words.
#
# Use a for loop to read words one by one.
#
# Check whether the current word is a restricted word using if condition.
#
# If the restricted word is found: • Display "Restricted word detected"
# • Stop the loop using break
#
# Otherwise display all safe words using print()

# %%
words=["present","absent","python","decline","hello","blocked","world"]

#rstricted word
restrict_word=["decline","blocked"]

for word in words:

  if word==restrict_word:
    print("restricted word detected")
    break
  print(word)
# Out:
# present
# absent
# python
# decline
# hello
# blocked
# world

# %% [markdown]
# Case Study – Arithmetic Calculator using User Defined Function
# Instructions
#
# Create a function called arth_cal()
#
# Pass two parameters to the function
#
# Inside the function:Perform addition, subtraction, multiplication
#
# Return all three values using multiple return statements
#
# Take two numbers from the user using input()
#
# Store returned values in separate variables
#
# Display:Sum, Difference, Multiplication

# %%
def num(a,b): #parameters
  s=a+b
  d=a-b
  m=a*b
  return s, d, m


#user input
a=int(input("enter the first num:"))
b=int(input("entr the second num"))



sum= num(a,b)
difference=num(a,b)
multiplication=num(a,b)

print(f"addition of 2 number:{sum}")
print(f"difference of 2 number:{difference}")
print(f"multipy of 2 number:{multiplication}")
# Out:
# enter the first num:45
# entr the second num32
# addition of 2 number:(77, 13, 1440)
# difference of 2 number:(77, 13, 1440)
# multipy of 2 number:(77, 13, 1440)

# %%
def num(a,b): #parameters
  s=a+b
  d=a-b
  m=a*b
  #return s, d, m

#user input
a=int(input("enter the first num:"))
b=int(input("entr the second num"))



sum= num(a,b)
difference=num(a,b)
multiplication=num(a,b)

print(f"addition of 2 number:{sum}")
print(f"difference of 2 number:{difference}")
print(f"multipy of 2 number:{multiplication}")
# Out:
# enter the first num:12
# entr the second num10
# addition of 2 number:22
# difference of 2 number:22
# multipy of 2 number:22

# %%
def calculator (a,b) :
  add = a+b
  div = a%b
  mul = a*b

  return add, div,mul

A = float(input("enter your number :"))
B = float(input("enter your Number :"))

addition= calculator(A,B)
division = calculator(A,B)
multiple = calculator(A,B)

print("Sum of Numbers :" , addition)
print("Division Of numbers :", division)
print("Multiplication Of Numbers"  ,multiple)

# %% [markdown]
# ## **Case Study – Employee Attendance Count System using continue**
#
# **Instructions:**
#
# 1. Create a list named `attendance` with values:
#    Present, Absent, Present, Leave, Present
#
# 2. Create count variables:
#
#    • present
#    • absent
#    • leave
#
# 3. Use a for loop to iterate through the attendance list.
#
# 4. Use continue statement to:
#    • Skip remaining conditions after counting Present employees
#
# 5. Count:
#    • Total Present employees
#    • Total Absent employees
#    • Total Leave employees
#
# 6. Display all counts using print()

# %%
attendence=["present","absent","present","leave","present","absent","leave"]
P=A=L=0
for i in attendence:
  if i == "present":
    P+=1
  elif i == "absent":
      A+=1
  else:
        L+=1
print(f"total present employees:{P}, total absent employees:{A},total leave employees:{L}")
# Out:
# total present employees:3, total absent employees:2,total leave employees:2

# %% [markdown]
# Case Study – String Analysis using List Comprehension
# **Instructions **
#
# Create a string variable called text
#
# Store any sentence or word inside the variable
#
# Use list comprehension to:
#
# Convert all characters into uppercase
#
# Extract only vowels from the string
#
# Extract only consonants from the string
#
# Display:
#
# Original string
#
# Uppercase characters
#
# Vowels list
#
# Consonants list
#
# String without spaces
#
# Print the output in a clean format using print() statements
